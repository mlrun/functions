# %% [markdown]
# ### tests

# %%
import mlrun
import os
mlrun.mlconf.dbpath = 'http://mlrun-api:8080'
mlrun.mlconf.hub_url = 'https://raw.githubusercontent.com/mlrun/functions/init_fixes/{name}/function.yaml'

# %%
xfn = mlrun.import_function('hub://arc_to_parquet')
# Out:
# /User/.pythonlibs/jupyter/lib/python3.6/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-19-640c55a14c98> in <module>
# ----> 1 xfn = mlrun.import_function('hub://arc_to_parquet')
#
# ~/mlrun/mlrun/run.py in import_function(url, secrets, db)
#     238
#     239     url = extend_hub_uri(url)
# --> 240     runtime = import_function_to_dict(url, secrets)
#     241     return new_function(runtime=runtime)
#     242
#
# ~/mlrun/mlrun/run.py in import_function_to_dict(url, secrets)
#     244 def import_function_to_dict(url, secrets=None):
# ...

# %%
db = mlrun.get_run_db().connect()
# Out:
# [mlrun] 2020-03-15 21:31:55,845 warning!, server (0.4.5) and client (0.4.6) ver dont match

# %%
db.list_functions('')
# Out:
# [{'kind': 'job',
#   'metadata': {'categories': ['fileutils', 'compression'],
#    'labels': {'author': 'yjb', 'stage': 'development'},
#    'name': 'arc-to-parquet',
#    'project': '',
#    'tag': 'latest',
#    'updated': '2020-03-15T21:23:10.268328+00:00'},
#   'spec': {'args': [],
#    'build': {'code_origin': 'https://raw.githubusercontent.com/mlrun/functions/master/arc_to_parquet/arc_to_parquet.py',
#     'commands': [],
#     'functionSourceCode': '...'},
#    'command': '',
#    'default_handler': 'arc_to_parquet',
#    'description': '',
#    'env': [],
#    'image': 'mlrun/ml-base:0.4.5',
#    'volume_mounts': [],
#    'volumes': []}},
#  {'kind': 'job',
#   'metadata': {'categories': ['fileutils', 'compression'],
#    'labels': {'author': 'yjb', 'stage': 'development'},
#    'name': 'arc-to-parquet',
#    'project': '',
#    'tag': 'latest',
#    'updated': '2020-03-15T21:23:10.287488+00:00'},
#   'spec': {'args': [],
# ...

# %%
dir(db)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_cache',
#  '_abc_negative_cache',
#  '_abc_negative_cache_version',
#  '_abc_registry',
#  '_path_of',
#  'api_call',
#  'base_url',
#  'connect',
#  'del_artifact',
#  'del_artifacts',
#  'del_run',
#  'del_runs',
#  'get_builder_status',
#  'get_function',
#  'get_log',
#  'kind',
#  'list_artifact_tags',
#  'list_artifacts',
#  'list_functions',
#  'list_projects',
#  'list_runs',
#  'password',
#  'read_artifact',
#  'read_metric',
#  'read_run',
#  'remote_builder',
#  'remote_start',
#  'remote_status',
#  'server_version',
# ...

# %%
fn = db.get_function('arc-to-parquet')
fn.apply(mlrun.mount_v3io())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-ec0e119573de> in <module>
#       1 fn = db.get_function('arc-to-parquet')
# ----> 2 fn.apply(mlrun.mount_v3io())
#
# AttributeError: 'dict' object has no attribute 'apply'

# %%
mlrun.import_function(fn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-ac106dcfb363> in <module>
# ----> 1 mlrun.import_function(fn)
#
# ~/mlrun/mlrun/run.py in import_function(url, secrets, db)
#     226     :returns: function object
#     227     """
# --> 228     if url.startswith('db://'):
#     229         url = url[5:]
#     230         project, name, tag = parse_function_uri(url)
#
# AttributeError: 'dict' object has no attribute 'startswith'

# %%
xfn = mlrun.import_function('arc_to_parquet')
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-3-a255aa9ab279> in <module>
# ----> 1 xfn = mlrun.import_function('arc_to_parquet')
#
# ~/mlrun/mlrun/run.py in import_function(url, secrets, db)
#     238
#     239     url = extend_hub_uri(url)
# --> 240     runtime = import_function_to_dict(url, secrets)
#     241     return new_function(runtime=runtime)
#     242
#
# ~/mlrun/mlrun/run.py in import_function_to_dict(url, secrets)
#     244 def import_function_to_dict(url, secrets=None):
#     245     """Load function spec from local/remote YAML file"""
# --> 246     obj = get_object(url, secrets)
#     247     runtime = yaml.load(obj, Loader=yaml.FullLoader)
#     248     remote = '://' in url
#
# ~/mlrun/mlrun/datastore.py in get_object(url, secrets, size, offset)
#      40     stores = StoreManager(secrets)
# ...
