# %% [markdown]
# # archive to parquet file

# %% [markdown]
# ## tests

# %%
import mlrun, os
mlrun.mlconf.dbpath="http://mlrun-api:8080"

# %% [markdown]
# **don't add a run-uid to the artifact path here, we need this file to be in a fixed location to avoid re-downloading the file, especially if its big**

# %%
FUNCTION = "arc_to_parquet"

task_params = {
    "name" : FUNCTION,
    "params" :  {
        "archive_url" : "https://archive.ics.uci.edu/ml/machine-learning-databases/00280/HIGGS.csv.gz",
        "header"      : ['labels', 'lepton_pT', 'lepton_eta', 'lepton_phi', 'missing_energy_magnitude', 
                         'missing_energy_phi', 'jet_1_pt', 'jet_1_eta', 'jet_1_phi', 'jet_1_b-tag', 
                         'jet_2_pt', 'jet_2_eta', 'jet_2_phi', 'jet_2_b-tag', 'jet_3_pt', 'jet_3_eta',
                         'jet_3_phi', 'jet_3_b-tag', 'jet_4_pt', 'jet_4_eta', 'jet_4_phi', 'jet_4_b-tag',
                         'm_jj', 'm_jjj', 'm_lv', 'm_jlv', 'm_bb', 'm_wbb', 'm_wwbb'],
        "key"         : "higgs"},
    "artifact_path"   : os.path.join(f"/User/functions/{FUNCTION}/artifacts")}

# %%
# load from functions library
func = mlrun.import_function('/User/functions/arc_to_parquet/function.yaml').apply(mlrun.mount_v3io())

# %%
# create a task
arc_to_parq_task = mlrun.NewTask(**task_params)

# %%
# run
run = func.run(arc_to_parq_task)
# Out:
# [mlrun] 2020-03-23 10:40:57,642 warning!, server (0.4.5) and client (0.4.6) ver dont match
# [mlrun] 2020-03-23 10:40:57,642 starting run arc_to_parquet uid=b8b60fafd9f742d688557b76b4b5d54d  -> http://mlrun-api:8080
# [mlrun] 2020-03-23 10:40:57,728 Job is running in the background, pod: arc-to-parquet-rzvx2
# [mlrun] 2020-03-23 10:41:24,441 warning!, server (0.4.5) and client (0.4.6) ver dont match
# [mlrun] 2020-03-23 10:41:24,479 warning!, server (0.4.5) and client (0.4.6) ver dont match
# [mlrun] 2020-03-23 10:41:24,491 destination file already exists
# [mlrun] 2020-03-23 10:41:24,506 log artifact higgs at /User/functions/arc_to_parquet/artifacts/higgs.pqt, size: None, db: Y
#
# [mlrun] 2020-03-23 10:41:24,515 run executed, status=completed
# final state: succeeded
# <style>
# .dictlist {
#   background-color: #b3edff;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
# ...
