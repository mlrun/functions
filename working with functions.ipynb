# %%
import mlrun
import os
mlrun.mlconf.dbpath = 'http://mlrun-api:8080'
mlrun.mlconf.hub_url = 'https://raw.githubusercontent.com/yjb-ds/functions/init_fixes/{name}/function.yaml'

# %% [markdown]
# # tests

# %% [markdown]
# ### parameters

# %%
ARCHIVE = "https://archive.ics.uci.edu/ml/machine-learning-databases/00280/HIGGS.csv.gz"

HEADER  = ['labels', 'lepton_pT', 'lepton_eta', 'lepton_phi', 'missing_energy_magnitude', 
           'missing_energy_phi', 'jet_1_pt', 'jet_1_eta', 'jet_1_phi', 'jet_1_b-tag', 
           'jet_2_pt', 'jet_2_eta', 'jet_2_phi', 'jet_2_b-tag', 'jet_3_pt', 'jet_3_eta',
           'jet_3_phi', 'jet_3_b-tag', 'jet_4_pt', 'jet_4_eta', 'jet_4_phi', 'jet_4_b-tag',
           'm_jj', 'm_jjj', 'm_lv', 'm_jlv', 'm_bb', 'm_wbb', 'm_wwbb']

DATA_PATH = '/User/functions/arc_to_parquet/examples/artifacts'

KEY       = 'higgs'

# %%
task = mlrun.NewTask(
    params = {
        'archive_url': ARCHIVE,
        'header'     : HEADER,
        'key'        : KEY},
    artifact_path=DATA_PATH)

# %% [markdown]
# ## from the mlrun function hub

# %%
xfn = mlrun.import_function('hub://arc_to_parquet:development')
# Out:
# /User/.pythonlibs/jupyter/lib/python3.6/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
xfn.run(task)
# Out:
# [mlrun] 2020-03-15 21:53:57,845 warning!, server (0.4.5) and client (0.4.6) ver dont match
# [mlrun] 2020-03-15 21:53:57,846 starting run arc-to-parquet-arc_to_parquet uid=f5c5b74d12d3485c82148489ae9a8bdd  -> http://mlrun-api:8080
# [mlrun] 2020-03-15 21:53:57,933 Job is running in the background, pod: arc-to-parquet-arc-to-parquet-ggznd
# Traceback (most recent call last):
#   File "/opt/conda/bin/mlrun", line 8, in <module>
#     sys.exit(main())
#   File "/opt/conda/lib/python3.7/site-packages/click/core.py", line 829, in __call__
#     return self.main(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/click/core.py", line 782, in main
#     rv = self.invoke(ctx)
#   File "/opt/conda/lib/python3.7/site-packages/click/core.py", line 1259, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/opt/conda/lib/python3.7/site-packages/click/core.py", line 1066, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/opt/conda/lib/python3.7/site-packages/click/core.py", line 610, in invoke
#     return callback(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/mlrun/__main__.py", line 176, in run
#     resp = fn.run(runobj, watch=watch, schedule=schedule)
#   File "/opt/conda/lib/python3.7/site-packages/mlrun/runtimes/base.py", line 311, in run
#     resp = self._run(runspec, execution)
#   File "/opt/conda/lib/python3.7/site-packages/mlrun/runtimes/local.py", line 90, in _run
#     mod, fn = load_module(self.spec.command, handler)
#   File "/opt/conda/lib/python3.7/site-packages/mlrun/runtimes/local.py", line 152, in load_module
#     spec.loader.exec_module(mod)
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "main.py", line 47, in <module>
#     part_cols = [],
# NameError: name 'DataItem' is not defined
# final state: failed
# <style>
# .dictlist {
#   background-color: #b3edff;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #ffe6cc;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #ffe6cc;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div title="f5c5b74d12d3485c82148489ae9a8bdd">...9a8bdd</div></td>
#       <td>0</td>
#       <td>Mar 15 21:54:00</td>
#       <td><div style="color: red;" title="error, check logs">error</div></td>
#       <td>arc-to-parquet-arc_to_parquet</td>
#       <td><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div></td>
#       <td></td>
#       <td><div class="dictlist">archive_url=https://archive.ics.uci.edu/ml/machine-learning-databases/00280/HIGGS.csv.gz</div><div class="dictlist">header=['labels', 'lepton_pT', 'lepton_eta', 'lepton_phi', 'missing_energy_magnitude', 'missing_energy_phi', 'jet_1_pt', 'jet_1_eta', 'jet_1_phi', 'jet_1_b-tag', 'jet_2_pt', 'jet_2_eta', 'jet_2_phi', 'jet_2_b-tag', 'jet_3_pt', 'jet_3_eta', 'jet_3_phi', 'jet_3_b-tag', 'jet_4_pt', 'jet_4_eta', 'jet_4_phi', 'jet_4_b-tag', 'm_jj', 'm_jjj', 'm_lv', 'm_jlv', 'm_bb', 'm_wbb', 'm_wwbb']</div><div class="dictlist">key=higgs</div></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result8b01d166-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result8b01d166-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result8b01d166" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result8b01d166-body"></iframe>
#   </div>
# </div>
# to track results use .show() or .logs() or in CLI:
# !mlrun get run f5c5b74d12d3485c82148489ae9a8bdd  , !mlrun logs f5c5b74d12d3485c82148489ae9a8bdd
# [mlrun] 2020-03-15 21:54:04,131 run executed, status=error
# runtime error: error, check logs
# ---------------------------------------------------------------------------
# RunError                                  Traceback (most recent call last)
# <ipython-input-31-567bf4f35950> in <module>
# ----> 1 xfn.run(task)
#
# ~/mlrun/mlrun/runtimes/base.py in run(self, runspec, handler, name, project, params, inputs, out_path, workdir, artifact_path, watch, schedule)
#     288                 result = self._post_run(task=runspec, err=err)
#     289                 return self._wrap_result(result, runspec, err=err)
# --> 290             return self._wrap_result(resp, runspec)
#     291
#     292         elif self._is_remote and not self._is_api_server and not self.kfp:
#
# ~/mlrun/mlrun/runtimes/base.py in _wrap_result(self, result, runspec, err)
#     356                 if self._is_remote and not self.is_child:
#     357                     print('runtime error: {}'.format(run.status.error))
# --> 358                 raise RunError(run.status.error)
#     359             return run
#     360
#
# RunError: error, check logs

# %% [markdown]
# ## from mlrun's db

# %%
xfn2 = mlrun.import_function('db://arc-to-parquet:latest')
# Out:
# [mlrun] 2020-03-15 21:54:52,754 warning!, server (0.4.5) and client (0.4.6) ver dont match

# %%
xfn2.run(task)
# Out:
# [mlrun] 2020-03-15 21:55:04,865 warning!, server (0.4.5) and client (0.4.6) ver dont match
# [mlrun] 2020-03-15 21:55:04,866 starting run arc-to-parquet-arc_to_parquet uid=ae6cf5a78edd4b44b23c908c0df70046  -> http://mlrun-api:8080
# [mlrun] 2020-03-15 21:55:04,949 Job is running in the background, pod: arc-to-parquet-arc-to-parquet-8tz62
# Traceback (most recent call last):
#   File "/opt/conda/bin/mlrun", line 8, in <module>
#     sys.exit(main())
#   File "/opt/conda/lib/python3.7/site-packages/click/core.py", line 829, in __call__
#     return self.main(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/click/core.py", line 782, in main
#     rv = self.invoke(ctx)
#   File "/opt/conda/lib/python3.7/site-packages/click/core.py", line 1259, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/opt/conda/lib/python3.7/site-packages/click/core.py", line 1066, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/opt/conda/lib/python3.7/site-packages/click/core.py", line 610, in invoke
#     return callback(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/mlrun/__main__.py", line 176, in run
#     resp = fn.run(runobj, watch=watch, schedule=schedule)
#   File "/opt/conda/lib/python3.7/site-packages/mlrun/runtimes/base.py", line 311, in run
#     resp = self._run(runspec, execution)
#   File "/opt/conda/lib/python3.7/site-packages/mlrun/runtimes/local.py", line 90, in _run
#     mod, fn = load_module(self.spec.command, handler)
#   File "/opt/conda/lib/python3.7/site-packages/mlrun/runtimes/local.py", line 152, in load_module
#     spec.loader.exec_module(mod)
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "main.py", line 47, in <module>
#     part_cols = [],
# NameError: name 'DataItem' is not defined
# final state: failed
# <style>
# .dictlist {
#   background-color: #b3edff;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #ffe6cc;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #ffe6cc;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div title="ae6cf5a78edd4b44b23c908c0df70046">...f70046</div></td>
#       <td>0</td>
#       <td>Mar 15 21:55:07</td>
#       <td><div style="color: red;" title="error, check logs">error</div></td>
#       <td>arc-to-parquet-arc_to_parquet</td>
#       <td><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div></td>
#       <td></td>
#       <td><div class="dictlist">archive_url=https://archive.ics.uci.edu/ml/machine-learning-databases/00280/HIGGS.csv.gz</div><div class="dictlist">header=['labels', 'lepton_pT', 'lepton_eta', 'lepton_phi', 'missing_energy_magnitude', 'missing_energy_phi', 'jet_1_pt', 'jet_1_eta', 'jet_1_phi', 'jet_1_b-tag', 'jet_2_pt', 'jet_2_eta', 'jet_2_phi', 'jet_2_b-tag', 'jet_3_pt', 'jet_3_eta', 'jet_3_phi', 'jet_3_b-tag', 'jet_4_pt', 'jet_4_eta', 'jet_4_phi', 'jet_4_b-tag', 'm_jj', 'm_jjj', 'm_lv', 'm_jlv', 'm_bb', 'm_wbb', 'm_wwbb']</div><div class="dictlist">key=higgs</div></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="resulte5ff1520-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="resulte5ff1520-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="resulte5ff1520" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="resulte5ff1520-body"></iframe>
#   </div>
# </div>
# to track results use .show() or .logs() or in CLI:
# !mlrun get run ae6cf5a78edd4b44b23c908c0df70046  , !mlrun logs ae6cf5a78edd4b44b23c908c0df70046
# [mlrun] 2020-03-15 21:55:11,064 run executed, status=error
# runtime error: error, check logs
# ---------------------------------------------------------------------------
# RunError                                  Traceback (most recent call last)
# <ipython-input-33-ea16d58dccdb> in <module>
# ----> 1 xfn2.run(task)
#
# ~/mlrun/mlrun/runtimes/base.py in run(self, runspec, handler, name, project, params, inputs, out_path, workdir, artifact_path, watch, schedule)
#     288                 result = self._post_run(task=runspec, err=err)
#     289                 return self._wrap_result(result, runspec, err=err)
# --> 290             return self._wrap_result(resp, runspec)
#     291
#     292         elif self._is_remote and not self._is_api_server and not self.kfp:
#
# ~/mlrun/mlrun/runtimes/base.py in _wrap_result(self, result, runspec, err)
#     356                 if self._is_remote and not self.is_child:
#     357                     print('runtime error: {}'.format(run.status.error))
# --> 358                 raise RunError(run.status.error)
#     359             return run
#     360
#
# RunError: error, check logs
