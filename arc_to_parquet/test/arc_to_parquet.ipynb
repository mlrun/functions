# %% [markdown]
# # archive to parquet file

# %% [markdown]
# ## tests

# %%
import mlrun, os

# %%
func = mlrun.import_function("hub://arc_to_parquet").apply(mlrun.mount_v3io())

# %%
task_params = {
    "name" : "tasks archive to parquet",
    "params" :  {
        "archive_url" : "https://archive.ics.uci.edu/ml/machine-learning-databases/00280/HIGGS.csv.gz",
        
        "header"      : ['labels', 'lepton_pT', 'lepton_eta', 'lepton_phi', 'missing_energy_magnitude', 
                         'missing_energy_phi', 'jet_1_pt', 'jet_1_eta', 'jet_1_phi', 'jet_1_b-tag', 
                         'jet_2_pt', 'jet_2_eta', 'jet_2_phi', 'jet_2_b-tag', 'jet_3_pt', 'jet_3_eta',
                         'jet_3_phi', 'jet_3_b-tag', 'jet_4_pt', 'jet_4_eta', 'jet_4_phi', 'jet_4_b-tag',
                         'm_jj', 'm_jjj', 'm_lv', 'm_jlv', 'm_bb', 'm_wbb', 'm_wwbb'],
        
        "key"         : "higgs"}}

# %%
run = func.run(mlrun.NewTask(**task_params), artifact_path="/User/artifacts")
# Out:
# [mlrun] 2020-03-24 21:31:40,173 starting run tasks archive to parquet uid=44092259e6b94ab0813d956e41375d58  -> http://mlrun-api:8080
# [mlrun] 2020-03-24 21:31:40,256 Job is running in the background, pod: tasks-archive-to-parquet-gfbs4
# [mlrun] 2020-03-24 21:31:44,538 Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/mlrun/runtimes/local.py", line 183, in exec_from_params
#     val = handler(*args_list)
#   File "main.py", line 65, in arc_to_parquet
#     dest_path = os.path.join(base_path, key+f".{file_ext}")
# NameError: name 'file_ext' is not defined
#
#
# [mlrun] 2020-03-24 21:31:44,546 exec error - name 'file_ext' is not defined
# [mlrun] 2020-03-24 21:31:44,572 run executed, status=error
# runtime error: name 'file_ext' is not defined
# name 'file_ext' is not defined
# final state: failed
# <style>
# .dictlist {
#   background-color: #b3edff;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #ffe6cc;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #ffe6cc;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div title="44092259e6b94ab0813d956e41375d58">...375d58</div></td>
#       <td>0</td>
#       <td>Mar 24 21:31:44</td>
#       <td><div style="color: red;" title="name 'file_ext' is not defined">error</div></td>
#       <td>tasks archive to parquet</td>
#       <td><div class="dictlist">host=tasks-archive-to-parquet-gfbs4</div><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div></td>
#       <td></td>
#       <td><div class="dictlist">archive_url=https://archive.ics.uci.edu/ml/machine-learning-databases/00280/HIGGS.csv.gz</div><div class="dictlist">header=['labels', 'lepton_pT', 'lepton_eta', 'lepton_phi', 'missing_energy_magnitude', 'missing_energy_phi', 'jet_1_pt', 'jet_1_eta', 'jet_1_phi', 'jet_1_b-tag', 'jet_2_pt', 'jet_2_eta', 'jet_2_phi', 'jet_2_b-tag', 'jet_3_pt', 'jet_3_eta', 'jet_3_phi', 'jet_3_b-tag', 'jet_4_pt', 'jet_4_eta', 'jet_4_phi', 'jet_4_b-tag', 'm_jj', 'm_jjj', 'm_lv', 'm_jlv', 'm_bb', 'm_wbb', 'm_wwbb']</div><div class="dictlist">key=higgs</div></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result35ca8993-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result35ca8993-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result35ca8993" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result35ca8993-body"></iframe>
#   </div>
# </div>
# to track results use .show() or .logs() or in CLI:
# !mlrun get run 44092259e6b94ab0813d956e41375d58  , !mlrun logs 44092259e6b94ab0813d956e41375d58
# [mlrun] 2020-03-24 21:31:46,428 run executed, status=error
# runtime error: name 'file_ext' is not defined
# ---------------------------------------------------------------------------
# RunError                                  Traceback (most recent call last)
# <ipython-input-11-b047c92de0c1> in <module>
# ----> 1 run = func.run(mlrun.NewTask(**task_params), artifact_path="/User/artifacts")
#
# ~/.pythonlibs/jupyter/lib/python3.6/site-packages/mlrun/runtimes/base.py in run(self, runspec, handler, name, project, params, inputs, out_path, workdir, artifact_path, watch, schedule)
#     288                 result = self._post_run(task=runspec, err=err)
#     289                 return self._wrap_result(result, runspec, err=err)
# --> 290             return self._wrap_result(resp, runspec)
#     291
#     292         elif self._is_remote and not self._is_api_server and not self.kfp:
#
# ~/.pythonlibs/jupyter/lib/python3.6/site-packages/mlrun/runtimes/base.py in _wrap_result(self, result, runspec, err)
#     356                 if self._is_remote and not self.is_child:
#     357                     print('runtime error: {}'.format(run.status.error))
# --> 358                 raise RunError(run.status.error)
#     359             return run
#     360
#
# RunError: name 'file_ext' is not defined
