# %%
import mlrun
import pandas as pd

# %%
project = mlrun.get_or_create_project("fastapi-openai",user_project=True,context="./src")

# %%
from openai_app import OpenAIModule

# %%
app = OpenAIModule(project=project)

# %%
app = mlrun.import_module("hub://openai")

# %%
app.fastapi_app.deploy()
